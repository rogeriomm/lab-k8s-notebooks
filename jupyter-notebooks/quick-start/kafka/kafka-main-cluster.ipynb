# %%
# !kubectl -n kafka-main-cluster get kafka -o yaml | yq
# Out:
# apiVersion: v1
# items:
#   - apiVersion: kafka.strimzi.io/v1beta2
#     kind: Kafka
#     metadata:
#       annotations:
#         kubectl.kubernetes.io/last-applied-configuration: |
#           {"apiVersion":"kafka.strimzi.io/v1beta2","kind":"Kafka","metadata":{"annotations":{},"name":"main","namespace":"kafka-main-cluster"},"spec":{"entityOperator":{"topicOperator":{},"userOperator":{}},"kafka":{"authorization":{"type":"simple"},"config":{"default.replication.factor":1,"min.insync.replicas":1,"offsets.topic.replication.factor":1,"transaction.state.log.min.isr":1,"transaction.state.log.replication.factor":1},"listeners":[{"authentication":{"type":"scram-sha-512"},"name":"plain","port":9092,"tls":false,"type":"internal"},{"authentication":{"type":"tls"},"name":"tls","port":9093,"tls":true,"type":"internal"},{"name":"external","port":9094,"tls":false,"type":"nodeport"}],"replicas":1,"storage":{"type":"jbod","volumes":[{"deleteClaim":false,"id":0,"size":"100Gi","type":"persistent-claim"}]},"version":"3.6.1"},"zookeeper":{"replicas":1,"storage":{"deleteClaim":false,"size":"100Gi","type":"persistent-claim"}}}}
#       creationTimestamp: "2024-01-31T16:10:45Z"
#       generation: 1
#       name: main
#       namespace: kafka-main-cluster
#       resourceVersion: "22028"
#       uid: 31d89ba2-7d57-415f-b614-7c4f24424c39
#     spec:
#       entityOperator:
#         topicOperator: {}
#         userOperator: {}
#       kafka:
#         authorization:
#           type: simple
#         config:
#           default.replication.factor: 1
#           min.insync.replicas: 1
#           offsets.topic.replication.factor: 1
#           transaction.state.log.min.isr: 1
#           transaction.state.log.replication.factor: 1
#         listeners:
#           - authentication:
#               type: scram-sha-512
#             name: plain
#             port: 9092
#             tls: false
#             type: internal
#           - authentication:
#               type: tls
#             name: tls
#             port: 9093
#             tls: true
#             type: internal
#           - name: external
#             port: 9094
#             tls: false
#             type: nodeport
#         replicas: 1
#         storage:
#           type: jbod
#           volumes:
#             - deleteClaim: false
#               id: 0
#               size: 100Gi
#               type: persistent-claim
#         version: 3.6.1
#       zookeeper:
#         replicas: 1
#         storage:
#           deleteClaim: false
#           size: 100Gi
#           type: persistent-claim
#     status:
#       clusterId: XiE_0lNFSLafD02XDgfvPQ
#       conditions:
#         - lastTransitionTime: "2024-01-31T16:18:37.931210116Z"
#           status: "True"
#           type: Ready
#       kafkaVersion: 3.6.1
#       listeners:
#         - addresses:
#             - host: main-kafka-bootstrap.kafka-main-cluster.svc
#               port: 9092
#           bootstrapServers: main-kafka-bootstrap.kafka-main-cluster.svc:9092
#           name: plain
#         - addresses:
#             - host: main-kafka-bootstrap.kafka-main-cluster.svc
#               port: 9093
#           bootstrapServers: main-kafka-bootstrap.kafka-main-cluster.svc:9093
#           certificates:
#             - |
#               -----BEGIN CERTIFICATE-----
#               MIIFLTCCAxWgAwIBAgIUSmNx/vw/u/87ha8Kj5EVvplhogQwDQYJKoZIhvcNAQEN
#               BQAwLTETMBEGA1UECgwKaW8uc3RyaW16aTEWMBQGA1UEAwwNY2x1c3Rlci1jYSB2
#               MDAeFw0yNDAxMzExNjEwNDZaFw0yNTAxMzAxNjEwNDZaMC0xEzARBgNVBAoMCmlv
#               LnN0cmltemkxFjAUBgNVBAMMDWNsdXN0ZXItY2EgdjAwggIiMA0GCSqGSIb3DQEB
#               AQUAA4ICDwAwggIKAoICAQCuvQ2zUMxS9qqQMueICH+Q9BYHdxn5fsseiLuBCaQf
#               eH4/mxJmStxPwXmGXh5uwI4rBtijt/xd+gtdJhHAO9tQRwH6gKGEP7JSkHI6o67Z
#               0gnhI3Yjjv3e5qWh+LV7vJAtz1lF04GkOJkdju935SgQTdHGfHybLh4q8YLOaMrl
#               VpBoMHGhCILvsib2/wEICSV3ncAE0W5wCFEX5QEUwJezBiUZE1TGH7ig8kPbcaon
#               PWlsZegul/bHf9ahbaSiysu8gFlxG5mY6ufByW90izAfebFKZRq4K+CtK9oi9HpM
#               KJr343/gPtVdSlKgF/O++CwEDsslZkgxhJx3G2hkw3diYWsw3E7f6To4DdH5BrBm
#               KDSUeSjs+fIBJIJ6xr22ad4pf+4ZonhvjPmMEJkxI6C0aL1jvsws/96eR63/Tggr
#               b9hYmEd22CdI4andxjf+0lXHxTW46dy3T6Sh75Y7hAboa6kO/Lfd+T9lS9+qtP9m
#               /XJ4PyP5MQzzQz3pXVPmkyVPUXPig1gwMeILa2aExscQPp2W2rIe82jV53mkcqaJ
#               +O2/JwMBQUhYe9Tpg7yzySxNsF2EMMiwC+vWbyx6I/b474Ut/1t+ewCW5TWeWnpa
#               7yzZ9zg/FzFrY86ExiUjQRqSHX3NRwhXWPrXR+trxpmkcq9xUexpkNFkGAHFJ2MG
#               awIDAQABo0UwQzAdBgNVHQ4EFgQU+ZinEjPZGrPIcac24Y680i58aZYwEgYDVR0T
#               AQH/BAgwBgEB/wIBADAOBgNVHQ8BAf8EBAMCAQYwDQYJKoZIhvcNAQENBQADggIB
#               AAXzBm13mNQVPafJmgP4cL5pRO1S2EqKAX6opfeGx18ChBoHu5oQuUDF4y/gSy+V
#               XysJG484qZt9g7LryI+++yrYBUhBe+sduSctlGA8bE4QYZKfvNbHJIO0VTszHWM1
#               CCgIgNb5qhbUMGUMXD4eu3U3jobG+IE1mzM9xcEJZflC2hL7Oy7p8l+Y9+jyo2fz
#               zmrUUQ01HBgt0AAdknrwCcLr5L8dCD7sXc2HMXcKpTLxVc0J6EwIYGrFO0n8G5mZ
#               wBku6wllRQ2T8FnwXwM+G8LLGI6dn/GLztaRSO8viZo7skLDMC+3GFvulYFGswQJ
#               CP7U8ZMD/Jgsg1scF/yiVg7YIQRDM3wgxpUmXDwktNfTmr1kyJXbaICLR/pFETEJ
#               ATyBTZTU26lIQrYQQXBg+pevFbsRq+gGOHl2EjoH9M1AswJUprBorH0IZlUD1bPh
#               2RJjOpi4D+9m8Mhaw2QoN8jl2zmEycx0fscQr084QPzQx/byQDiqvLXFu3Ogw34J
#               4O3lyNg1abY65LFuN7VUhbJGkZJeufc2k6LEG4nzHk4nfU8eJqmetqh5SbT7VtPv
#               Ol+ixMAUUOljVQxOjID61mg+I/uMplysSNzFfWGKTFDfybnxokxyTFFnVqfQj6FD
#               knW7BLD/cxXRhPqu/BziaRtHoNtpKKWlSsVGD9CgESE/
#               -----END CERTIFICATE-----
#           name: tls
#         - addresses:
#             - host: 192.168.49.3
#               port: 32270
#           bootstrapServers: 192.168.49.3:32270
#           name: external
#       observedGeneration: 1
#       operatorLastSuccessfulVersion: 0.39.0
# kind: List
# metadata:
#   resourceVersion: ""

# %%
# !kubectl -n kafka-main-cluster get serviceaccount my-connect-connect -o yaml | yq
# Out:
# apiVersion: v1
# kind: ServiceAccount
# metadata:
#   creationTimestamp: "2024-01-31T16:10:45Z"
#   labels:
#     app.kubernetes.io/instance: my-connect
#     app.kubernetes.io/managed-by: strimzi-cluster-operator
#     app.kubernetes.io/name: kafka-connect
#     app.kubernetes.io/part-of: strimzi-my-connect
#     strimzi.io/cluster: my-connect
#     strimzi.io/component-type: kafka-connect
#     strimzi.io/kind: KafkaConnect
#     strimzi.io/name: my-connect-connect
#   name: my-connect-connect
#   namespace: kafka-main-cluster
#   ownerReferences:
#     - apiVersion: kafka.strimzi.io/v1beta2
#       blockOwnerDeletion: false
#       controller: false
#       kind: KafkaConnect
#       name: my-connect
#       uid: 73fccb6f-4921-4c43-9d8b-350d0a30b72a
#   resourceVersion: "19302"
#   uid: 383defd5-f698-44b6-8b90-64782a7dbb51
