# %%
# !kubectl -n kafka-main-cluster get pods main-registry-schema-registry-0 -o yaml | yq
# Out:
# apiVersion: v1
# kind: Pod
# metadata:
#   creationTimestamp: "2024-02-07T12:10:52Z"
#   generateName: main-registry-schema-registry-
#   labels:
#     app.kubernetes.io/instance: main-registry
#     app.kubernetes.io/managed-by: Helm
#     app.kubernetes.io/name: schema-registry
#     apps.kubernetes.io/pod-index: "0"
#     controller-revision-hash: main-registry-schema-registry-567f89cf55
#     helm.sh/chart: schema-registry-14.0.1
#     statefulset.kubernetes.io/pod-name: main-registry-schema-registry-0
#   name: main-registry-schema-registry-0
#   namespace: kafka-main-cluster
#   ownerReferences:
#     - apiVersion: apps/v1
#       blockOwnerDeletion: true
#       controller: true
#       kind: StatefulSet
#       name: main-registry-schema-registry
#       uid: a2634253-d218-480a-a0aa-5b50c0daffcf
#   resourceVersion: "42161"
#   uid: 7bacaf3d-ba6f-49b0-ac7f-fe0a65c92304
# spec:
#   affinity:
#     podAntiAffinity:
#       preferredDuringSchedulingIgnoredDuringExecution:
# ...
