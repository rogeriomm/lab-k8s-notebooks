# %%
# !kubectl -n kafka-main-cluster get kafkaconnect my-connect -o yaml | yq
# Out:
# apiVersion: kafka.strimzi.io/v1beta2
# kind: KafkaConnect
# metadata:
#   annotations:
#     kubectl.kubernetes.io/last-applied-configuration: |
# ...

# %%
# !kubectl -n kafka-main-cluster get pod my-connect-connect-0 -o yaml | yq
# Out:
# apiVersion: v1
# kind: Pod
# metadata:
#   annotations:
#     cni.projectcalico.org/containerID: 8c888b56e46e951fea20df621cd42751c5f76dd03879907c7fc2301e713b204e
#     cni.projectcalico.org/podIP: 10.244.60.58/32
#     cni.projectcalico.org/podIPs: 10.244.60.58/32
#     strimzi.io/auth-hash: "-461211683"
#     strimzi.io/logging-appenders-hash: 06ee78c4
#     strimzi.io/revision: 6904d643
#   creationTimestamp: "2024-02-23T10:32:38Z"
#   labels:
#     app.kubernetes.io/instance: my-connect
#     app.kubernetes.io/managed-by: strimzi-cluster-operator
#     app.kubernetes.io/name: kafka-connect
#     app.kubernetes.io/part-of: strimzi-my-connect
#     statefulset.kubernetes.io/pod-name: my-connect-connect-0
#     strimzi.io/cluster: my-connect
#     strimzi.io/component-type: kafka-connect
#     strimzi.io/controller: strimzipodset
#     strimzi.io/controller-name: my-connect-connect
#     strimzi.io/kind: KafkaConnect
#     strimzi.io/name: my-connect-connect
# ...

# %%
# !kubectl -n kafka-main-cluster get pod my-connect-connect-0 -o jsonpath='{.spec.serviceAccount}'
# Out:
# my-connect-connect

# %%
# !kubectl -n kafka-main-cluster get serviceaccount my-connect-connect -o yaml | yq
# Out:
# apiVersion: v1
# kind: ServiceAccount
# metadata:
#   creationTimestamp: "2024-02-07T10:54:26Z"
#   labels:
#     app.kubernetes.io/instance: my-connect
#     app.kubernetes.io/managed-by: strimzi-cluster-operator
#     app.kubernetes.io/name: kafka-connect
#     app.kubernetes.io/part-of: strimzi-my-connect
#     strimzi.io/cluster: my-connect
#     strimzi.io/component-type: kafka-connect
#     strimzi.io/kind: KafkaConnect
#     strimzi.io/name: my-connect-connect
#   name: my-connect-connect
#   namespace: kafka-main-cluster
#   ownerReferences:
#     - apiVersion: kafka.strimzi.io/v1beta2
#       blockOwnerDeletion: false
#       controller: false
#       kind: KafkaConnect
#       name: my-connect
#       uid: 7bdc2f74-6ba8-4304-8d0b-a3337c3d4d6f
#   resourceVersion: "8960"
#   uid: df12e585-9604-4f48-b899-d63c700aaba7

# %% [markdown]
#    * https://strimzi.io/docs/operators/0.30.0/full/configuring#installing-your-own-ca-certificates-str: 9.1.2. Installing your own CA certificates
#       * **"This procedure describes how to install your own CA certificates and keys instead of using the CA certificates and private keys generated by the Cluster Operator"**

# %%
# !kubecolor -n kafka-main-cluster get secret
# Out:
# /usr/bin/sh: line 1: kubecolor: command not found

# %%
# !kubectl -n kafka-main-cluster get secret main-clients-ca-cert -o yaml | yq
# Out:
# apiVersion: v1
# data:
#   ca.crt: ...
#   ca.p12: ...
#   ca.password: R05rdzNGZ0hlS0NS
# kind: Secret
# metadata:
#   annotations:
#     strimzi.io/ca-cert-generation: "0"
#   creationTimestamp: "2024-02-07T10:54:28Z"
#   labels:
#     app.kubernetes.io/instance: main
#     app.kubernetes.io/managed-by: strimzi-cluster-operator
#     app.kubernetes.io/name: certificate-authority
#     app.kubernetes.io/part-of: strimzi-main
#     strimzi.io/cluster: main
#     strimzi.io/component-type: certificate-authority
#     strimzi.io/kind: Kafka
#     strimzi.io/name: strimzi
#   name: main-clients-ca-cert
#   namespace: kafka-main-cluster
#   ownerReferences:
#     - apiVersion: kafka.strimzi.io/v1beta2
#       blockOwnerDeletion: false
#       controller: false
#       kind: Kafka
#       name: main
#       uid: 543a3cff-b8b0-4733-be1f-6a379aad4fa2
#   resourceVersion: "9046"
#   uid: 93bd450a-6045-47d9-9ff0-a0250cc8d9da
# type: Opaque
